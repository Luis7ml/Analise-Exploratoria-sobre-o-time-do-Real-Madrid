# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dados = pd.read_csv('Tabela_Real_Madrid.csv', sep=',')
dados.columns = dados.columns.str.strip()
dados
# Out:
#        Season        Squad Country        Comp LgRank  MP   W   D   L   GF  \
# 0   2025-2026  Real Madrid  es ESP  1. La Liga    2nd  20  15   3   2   43
# 1   2024-2025  Real Madrid  es ESP  1. La Liga    2nd  38  26   6   6   78
# 2   2023-2024  Real Madrid  es ESP  1. La Liga    1st  38  29   8   1   87
# 3   2022-2023  Real Madrid  es ESP  1. La Liga    2nd  38  24   6   8   75
# 4   2021-2022  Real Madrid  es ESP  1. La Liga    1st  38  26   8   4   80
# 5   2020-2021  Real Madrid  es ESP  1. La Liga    2nd  38  25   9   4   67
# 6   2019-2020  Real Madrid  es ESP  1. La Liga    1st  38  26   9   3   70
# 7   2018-2019  Real Madrid  es ESP  1. La Liga    3rd  38  21   5  12   63
# 8   2017-2018  Real Madrid  es ESP  1. La Liga    3rd  38  22  10   6   94
# 9   2016-2017  Real Madrid  es ESP  1. La Liga    1st  38  29   6   3  106
# 10  2015-2016  Real Madrid  es ESP  1. La Liga    2nd  38  28   6   4  110
# ...

# %%
dados.describe()
# Out:
#               MP          W          D          L          GF         GA  \
# count  38.000000  38.000000  38.000000  38.000000   38.000000  38.000000
# mean   37.736842  24.026316   7.394737   6.315789   81.947368  38.342105
# std     3.090388   4.096715   2.880873   3.297052   17.882420   8.899670
# min    20.000000  15.000000   2.000000   1.000000   43.000000  17.000000
# 25%    38.000000  21.000000   5.250000   4.000000   70.000000  32.250000
# 50%    38.000000  24.500000   7.000000   6.000000   78.000000  38.000000
# 75%    38.000000  26.750000   9.000000   8.000000   93.250000  43.500000
# max    42.000000  32.000000  14.000000  12.000000  121.000000  62.000000
#
#               GD         Pts  Attendance
# count  38.000000   38.000000   11.000000
# mean   43.605263   75.263158   63.975545
# std    20.275854   14.949797   11.466956
# min    10.000000   45.000000   41.235000
# 25%    26.000000   63.750000   58.844500
# 50%    44.500000   78.000000   69.807000
# ...

# %%
dados = dados[['Season', 'LgRank', 'MP', 'W', 'D', 'L', 'GF', 'GA', 'Pts', 'Top Team Scorer']]
campeoes = dados.loc[dados['LgRank'] == '1st']
campeoes
artilheros = campeoes['Top Team Scorer']
campeoes.plot(x='Top Team Scorer', y='GF', kind='bar', color='red')

# AQUI PROCURO ARTILHEIROS EM ANOS QUE O ELENCO FOI CAMPEÃO
# Out:
# <Axes: xlabel='Top Team Scorer'>

# %%
campeoes.plot(x='Season', y='W', kind='barh', color='Blue')
plt.xticks(rotation=15)
plt.tight_layout()
plt.show()
np.median(campeoes['W'])
# Verifico a quantia minima de vitorias que o time ja teve
# Out:
# np.float64(26.0)

# %%
campeoes.plot(x='LgRank', y='Pts', kind='line', color='green')

# Entendo quantos pontos foram necessarios para conseguir o titulo
# Out:
# <Axes: xlabel='LgRank'>

# %%
# CONCLUSÃO
# Jude bellingham após ser mudado de possição decaiu muito o redimento
# A media é de 26 vitorias por campeonato
# Que a cada ano que passa os numeros de pontos detem a diminuir, isso mostra que o futebol espanhol está evoluindo com o passar dos anos.
